# %%
import pandas as pd

# %%
df = pd.read_csv('yelp.csv')
df.dropna()
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# ...                      ...         ...                     ...    ...
# 9995  VY_tvNUCCXGXQeSvJl757Q  2012-07-28  Ubyfp2RSDYW0g7Mbr8N3iA      3
# 9996  EKzMHI1tip8rC1-ZAy64yg  2012-01-18  2XyIOQKbVFb6uXQdJ0RzlQ      4
# 9997  53YGfwmbW73JhFiemNeyzQ  2010-11-16  jyznYkIbpqVmlsZxSDSypA      4
# 9998  9SKdOoDHcFoxK5ZtsgHJoA  2012-12-02  5UKq9WQE1qQbJ0DJbc-B6Q      2
# 9999  pF7uRzygyZsltbmVpjIyvw  2010-10-16  vWSmOhg2ID1MNZHaWapGbA      5
#
#                                                    text    type  \
# 0     My wife took me here on my birthday for breakf...  review
# 1     I have no idea why some people give bad review...  review
# 2     love the gyro plate. Rice is so good and I als...  review
# 3     Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4     General Manager Scott Petello is a good egg!!!...  review
# ...                                                 ...     ...
# 9995  First visit...Had lunch here today - used my G...  review
# 9996  Should be called house of deliciousness!\n\nI ...  review
# 9997  I recently visited Olive and Ivy for business ...  review
# 9998  My nephew just moved to Scottsdale recently so...  review
# 9999  4-5 locations.. all 4.5 star average.. I think...  review
#
#                      user_id  cool  useful  funny
# 0     rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1     0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2     0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3     uZetl9T0NcROGOyFfughhg     1       2      0
# 4     vYmM4KTsC8ZfQBg-j5MWkw     0       0      0
# ...                      ...   ...     ...    ...
# 9995  _eqQoPtQ3e3UxLE4faT6ow     1       2      0
# 9996  ROru4uk5SaYc3rg8IU7SQw     0       0      0
# 9997  gGbN1aKQHMgfQZkqlsuwzg     0       0      0
# 9998  0lyVoNazXa20WzUyZPLaQQ     0       0      0
# 9999  KSBFytcdjPKZgXKQnYQdkA     0       0      0
#
# [10000 rows x 10 columns]

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer
import nltk
#nltk.download('punkt')
tokenizer = RegexpTokenizer(r'\w+')
ps = PorterStemmer()

temp = []
stopWords = ['a', 'the', 'is', 'are', '\n', "'s"]
newDF = pd.DataFrame(columns = ['Review','Rating'])


for idx, row in df.iterrows():
    rating = row['stars']
    rev = row['text']
    rev = tokenizer.tokenize(rev)
    for word in rev:
        if word.lower() not in stopWords:
            if word == "'t":
                temp.append('not')
            elif word == "'m":
                temp.append('am')
            else:
                temp.append(ps.stem(word))
    newDF = newDF.append({'Review':temp,'Rating':rating},ignore_index=True)
    temp = []
# In the forum of an array [[sent1], [sent2], ...] -> sentences are separated into words ['word1', 'word2', ...]

# %%
# Structure of newDF => Review | Rating
#print(newDF['Review'][:5])
vocab = {}
idx = 1
maxlen = 0
for seq in newDF['Review']:
    maxlen = max(len(seq),maxlen)
    for word in seq:
        if word not in vocab:
            vocab[word] = idx
            idx+=1
print(vocab)
print(maxlen)
# Out:
# {'my': 1, 'wife': 2, 'took': 3, 'me': 4, 'here': 5, 'on': 6, 'birthday': 7, 'for': 8, 'breakfast': 9, 'and': 10, 'it': 11, 'wa': 12, 'excel': 13, 'weather': 14, 'perfect': 15, 'which': 16, 'made': 17, 'sit': 18, 'outsid': 19, 'overlook': 20, 'their': 21, 'ground': 22, 'an': 23, 'absolut': 24, 'pleasur': 25, 'our': 26, 'waitress': 27, 'food': 28, 'arriv': 29, 'quickli': 30, 'semi': 31, 'busi': 32, 'saturday': 33, 'morn': 34, 'look': 35, 'like': 36, 'place': 37, 'fill': 38, 'up': 39, 'pretti': 40, 'so': 41, 'earlier': 42, 'you': 43, 'get': 44, 'better': 45, 'do': 46, 'yourself': 47, 'favor': 48, 'bloodi': 49, 'mari': 50, 'phenomen': 51, 'simpli': 52, 'best': 53, 'i': 54, 've': 55, 'ever': 56, 'had': 57, 'm': 58, 'sure': 59, 'they': 60, 'onli': 61, 'use': 62, 'ingredi': 63, 'from': 64, 'garden': 65, 'blend': 66, 'them': 67, 'fresh': 68, 'when': 69, 'order': 70, 'amaz': 71, 'while': 72, 'everyth': 73, 'menu': 74, 'white': 75, 'truffl': 76, 'scrambl': 77, 'egg': 78, 'veget': 79, 'skillet': 80, 'tasti': 81, 'delici': 82, 'came': 83, 'with': 84, '2': 85, 'piec': 86, 'of': 87, 'griddl': 88, 'bread': 89, 'meal': 90, 'complet': 91, 'toast': 92, 'anyway': 93, 'can': 94, 't': 95, 'wait': 96, 'to': 97, 'go': 98, 'back': 99, 'have': 100, 'no': 101, 'idea': 102, 'whi': 103, 'some': 104, 'peopl': 105, 'give': 106, 'bad': 107, 'review': 108, 'about': 109, 'thi': 110, 'goe': 111, 'show': 112, 'pleas': 113, 'everyon': 114, 'probabl': 115, 'gripe': 116, 'someth': 117, 'that': 118, 'own': 119, 'fault': 120, 'there': 121, 'mani': 122, 'in': 123, 'ani': 124, 'case': 125, 'friend': 126, 'at': 127, '5': 128, '50': 129, 'pm': 130, 'past': 131, 'sunday': 132, 'crowd': 133, 'more': 134, 'than': 135, 'thought': 136, 'even': 137, 'we': 138, 'would': 139, 'forev': 140, 'seat': 141, 'but': 142, 'said': 143, 'll': 144, 'be': 145, 'girl': 146, 'come': 147, 'someon': 148, 'els': 149, 'were': 150, '52': 151, 'waiter': 152, 'got': 153, 'drink': 154, 'veri': 155, 'pleasant': 156, 'host': 157, 'us': 158, 'server': 159, 'price': 160, 'good': 161, 'as': 162, 'well': 163, 'onc': 164, 'decid': 165, 'what': 166, 'want': 167, '6': 168, '02': 169, 'share': 170, 'bake': 171, 'spaghetti': 172, 'calzon': 173, 'small': 174, 's': 175, 'beef': 176, 'pizza': 177, 'both': 178, 'tri': 179, 'huge': 180, 'smallest': 181, 'one': 182, 'person': 183, '11': 184, 'awesom': 185, 'doe': 186, 'sweetish': 187, 'sauc': 188, 'how': 189, 'box': 190, 'part': 191, 'take': 192, 'home': 193, 'out': 194, 'door': 195, 'by': 196, '42': 197, 'great': 198, 'not': 199, 'these': 200, 'thing': 201, 'becaus': 202, 'all': 203, 'seriou': 204, 'issu': 205, 'love': 206, 'gyro': 207, 'plate': 208, 'rice': 209, 'also': 210, 'dig': 211, 'candi': 212, 'select': 213, 'rosi': 214, 'dakota': 215, 'chaparr': 216, 'dog': 217, 'park': 218, 'conveni': 219, 'surround': 220, 'lot': 221, 'path': 222, 'desert': 223, 'xeriscap': 224, 'basebal': 225, 'field': 226, 'ballpark': 227, 'lake': 228, 'duck': 229, 'scottsdal': 230, 'rec': 231, 'dept': 232, 'wonder': 233, 'job': 234, 'keep': 235, 'clean': 236, 'shade': 237, 'find': 238, 'trash': 239, 'poopi': 240, 'pick': 241, 'mitt': 242, 'locat': 243, 'over': 244, 'fenc': 245, 'area': 246, 'let': 247, 'run': 248, 'play': 249, 'sniff': 250, 'gener': 251, 'manag': 252, 'scott': 253, 'petello': 254, 'into': 255, 'detail': 256, 'assur': 257, 'if': 258, 'albeit': 259, 'rare': 260, 'speak': 261, 'treat': 262, 'guy': 263, 'respect': 264, 'state': 265, 'your': 266, 'd': 267, 'surpris': 268, 'don': 269, 'walk': 270, 'total': 271, 'satisfi': 272, 'just': 273, 'did': 274, 'alway': 275, 'say': 276, 'mistak': 277, 'inevit': 278, 'recov': 279, 'import': 280, 'thank': 281, 'hi': 282, 'staff': 283, 'custom': 284, 'life': 285, 'quiessenc': 286, 'put': 287, 'beauti': 288, 'full': 289, 'window': 290, 'earthi': 291, 'wooden': 292, 'wall': 293, 'feel': 294, 'warmth': 295, 'insid': 296, 'restaur': 297, 'perch': 298, 'middl': 299, 'farm': 300, 'seem': 301, 'fairli': 302, 'tuesday': 303, 'secur': 304, 'reser ...
# 899

# %%
import numpy as np
import time
#print(len(newDF))
EncodedInput = np.zeros((len(newDF),maxlen), dtype = 'int32')
rowIdx = 0
colIdx = 0
for seq in newDF['Review']:
    for word in seq:
        EncodedInput[colIdx,rowIdx] = vocab[word]
        rowIdx += 1
    rowIdx = 0
    colIdx += 1
# word coded arr in row and col per review

# %%
RatingOutput = np.zeros((len(newDF),1), dtype = 'int8')
idx = 0
for rating in newDF['Rating']:
    RatingOutput[idx,0] = rating
    idx+=1
# 1 col of ratings, 1 elemnt per row

# %%
from gensim.models import Word2Vec
corpus = newDF['Review']
# Initialize and train Word2Vec model
model = Word2Vec(sentences=corpus, window=10, min_count=5)
model.train(corpus, total_examples=len(corpus), epochs=10)

# Access trained word embeddings
embeddings = model.wv

# %%
embeddings.most_similar(positive=['good','quick','nice','delic'], negative=['bad','rude'])
# Out:
# [('tasti', 0.6917038559913635),
#  ('yummi', 0.6204665899276733),
#  ('delici', 0.6111957430839539),
#  ('hearti', 0.5835433006286621),
#  ('uniqu', 0.5669063329696655),
#  ('fantast', 0.5657705068588257),
#  ('superb', 0.5609145760536194),
#  ('mmmm', 0.55510014295578),
#  ('fresh', 0.5510253310203552),
#  ('delish', 0.5446157455444336)]

# %%
embVec = model.wv.vectors

# %%
from sklearn.cluster import KMeans

def cosSim(elA, elB):
    # Retrieve word embeddings for the two words
    embedding_a = embeddings[elA]
    embedding_b = embeddings[elB]

# Normalize embeddings (optional)
    embedding_a = embedding_a / np.linalg.norm(embedding_a)
    embedding_b = embedding_b / np.linalg.norm(embedding_b)

# Calculate cosine similarity
    cosine_similarity = np.dot(embedding_a, embedding_b)
    return cosine_similarity
# Print the similarity score
#print("Cosine Similarity:", cosine_similarity)

# %%
print(embeddings.key_to_index)
# Out:
# {'and': 0, 'i': 1, 'to': 2, 'it': 3, 'of': 4, 'wa': 5, 'for': 6, 'in': 7, 'that': 8, 'you': 9, 'my': 10, 'with': 11, 'but': 12, 'thi': 13, 'they': 14, 's': 15, 'on': 16, 'we': 17, 'have': 18, 't': 19, 'not': 20, 'place': 21, 'had': 22, 'good': 23, 'so': 24, 'be': 25, 'at': 26, 'food': 27, 'were': 28, 'as': 29, 'like': 30, 'there': 31, 'great': 32, 'go': 33, 'if': 34, 'all': 35, 'get': 36, 'me': 37, 'time': 38, 'out': 39, 'just': 40, 'here': 41, 'veri': 42, 'one': 43, 'can': 44, 'or': 45, 'their': 46, 'order': 47, 'from': 48, 'up': 49, 'when': 50, 'our': 51, 'realli': 52, 'about': 53, 'some': 54, 'servic': 55, 'would': 56, 'what': 57, 'love': 58, 'an': 59, 'been': 60, 'tri': 61, 'your': 62, 'which': 63, 'back': 64, 'more': 65, 'will': 66, 've': 67, 'onli': 68, 'don': 69, 'also': 70, 'by': 71, 'no': 72, 'other': 73, 'make': 74, 'nice': 75, 'm': 76, 'do': 77, 'too': 78, 'even': 79, 'ha': 80, 'restaur': 81, 'well': 82, 'littl': 83, 'look': 84, 'want': 85, 'becaus': 86, 'price': 87, 'them': 88, 'come': 89, 'alway': 90, 'than': 91, 'he': 92, 'best': 93, 'us': 94, 'she': 95, 'drink': 96, 'got': 97, 'after': 98, 'thing': 99, 'pretti': 100, 'know': 101, 'wait': 102, 'menu': 103, 'chicken': 104, 'much': 105, 'bar': 106, 'think': 107, 'eat': 108, 'peopl': 109, 'say': 110, 'first': 111, 'night': 112, 'over': 113, 'tast': 114, 'take': 115, 'didn': 116, 'could': 117, 'fri': 118, 'friendli': 119, 'never': 120, 'better': 121, 'am': 122, 'way': 123, 'day': 124, 'went': 125, 'pizza': 126, 'salad': 127, 'staff': 128, 'did': 129, 'off': 130, 'then': 131, 'tabl': 132, 'who': 133, 'chees': 134, '2': 135, 'friend': 136, 'hour': 137, 're': 138, 'ask': 139, 'how': 140, 'sauc': 141, 'star': 142, 'right': 143, 'delici': 144, 'lot': 145, 'two': 146, 'locat': 147, 'need': 148, 'made': 149, 'few': 150, 'work': 151, 'give': 152, 'see': 153, 'came': 154, 'flavor': 155, 'lunch': 156, 'ani': 157, 'now': 158, 'again': 159, 'enjoy': 160, '5': 161, 'experi': 162, 'fresh': 163, 'meal': 164, 'use': 165, 'new': 166, 'review': 167, 'sandwich': 168, 'still': 169, 'definit': 170, '3': 171, 'down': 172, 'find': 173, 'while': 174, 'll': 175, 'feel': 176, 'befor': 177, 'sure': 178, 'year': 179, 'her': 180, 'burger': 181, 'sinc': 182, 'happi': 183, 'side': 184, 'serv': 185, 'around': 186, 'dish': 187, 'area': 188, 'someth': 189, 'amaz': 190, 'bit': 191, 'most': 192, 'beer': 193, 'ever': 194, 'seem': 195, 'next': 196, 'everyth': 197, 'd': 198, 'everi': 199, 'though': 200, 'mani': 201, 'top': 202, 'said': 203, 'walk': 204, 'recommend': 205, 'bad': 206, 'visit': 207, 'dinner': 208, 'favorit': 209, 'store': 210, 'where': 211, 'into': 212, 'last': 213, 'busi': 214, 'check': 215, 'anoth': 216, 'phoenix': 217, 'special': 218, 'small': 219, '4': 220, 'minut': 221, 'help': 222, 'big': 223, 'both': 224, 'open': 225, 'home': 226, 'select': 227, 'seat': 228, 'wine': 229, 'park': 230, 'sweet': 231, 'hi': 232, 'bread': 233, 'room': 234, 'server': 235, 'tasti': 236, 'call': 237, 'differ': 238, 'hot': 239, 'wasn': 240, 'clean': 241, 'meat': 242, 'reason': 243, 'awesom': 244, 'enough': 245, '1': 246, 'shop': 247, 'long': 248, 'start': 249, 'actual': 250, 'atmospher': 251, 'live': 252, 'coffe': 253, 'offer': 254, 'worth': 255, 'kind': 256, 'end': 257, 'expect': 258, 'should': 259, 'took': 260, 'breakfast': 261, 'usual': 262, 'old': 263, 'custom': 264, 'ok': 265, 'perfect': 266, 'item': 267, 'stop': 268, '10': 269, 'excel': 270, 'plate': 271, 'roll': 272, 'sit': 273, 'these': 274, 'huge': 275, 'noth': 276, 'taco': 277, 'close': 278, 'found': 279, 'guy': 280, 'cook': 281, 'person': 282, 'those': 283, 'thought': 284, 'free': 285, 'probabl': 286, 'qualiti': 287, 'same': 288, 'ice': 289, 'decid': 290, 'spot': 291, 'scottsdal': 292, 'hous': 293, 'quit': 294, 'onc': 295, 'disappoint': 296, 'anyth': 297, 'cool': 298, 'let': 299, 'howev': 300, 'larg': 301, 'kid': 302, 'mayb': 303, 'super': 304, 'sushi': 305, 'potato': 306, 'full': 307, 'rice': 308, 'week': 309, 'cream': 310, 'town': 311, 'whi': 312, ...

# %%
from sklearn.preprocessing import normalize

import warnings
warnings.filterwarnings("ignore")
# Retrieve word embeddings
embeddings = model.wv.vectors

# Normalize embeddings
normalized_embeddings = normalize(embeddings)

# Check for missing or invalid values
if np.isnan(normalized_embeddings).any() or np.isinf(normalized_embeddings).any():
    raise ValueError("Input data contains NaN or infinite values.")

# Apply K-means clustering
num_clusters = 5  # Specify the desired number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=42)

try:
    cluster_labels = kmeans.fit_predict(normalized_embeddings)
except Exception as e:
    print("Error:", e)
    print("Ensure the input data is properly formatted and valid.")
    exit()

# Get the words and their corresponding cluster labels
words = model.wv.index_to_key
word_clusters = dict(zip(words, cluster_labels))

# Print words and their cluster labels
for word, label in word_clusters.items():
    print(f"{word}: Cluster {label}")
# Out:
# Error: 'NoneType' object has no attribute 'split'
# Ensure the input data is properly formatted and valid.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 28
#      26 # Get the words and their corresponding cluster labels
#      27 words = model.wv.index_to_key
# ---> 28 word_clusters = dict(zip(words, cluster_labels))
#      30 # Print words and their cluster labels
#      31 for word, label in word_clusters.items():
#
# NameError: name 'cluster_labels' is not defined
